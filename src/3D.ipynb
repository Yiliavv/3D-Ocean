# %%
# %reload_ext autoreload
# %autoreload 2
import sys
import arrow

sys.path.append('/home/morisi/Workspace/3D-Ocean')

from src.config.area import Area
from src.trainer.base import BaseTrainer, BasePrediction
from src.dataset.Argo import Argo3DTemperatureDataset, ArgoDepthMap
from src.models.Profile.UNet3D import UNet3D

# %%
area = Area("global_rf_model", [-180, 180], [-80, 80], "global")

depth = [0, 10]

dataset_params = {
    "depth": depth,
    "resolution": 2
}

# 训练器参数
trainer_params = {
    "epochs": 500,
    "batch_size": 32,
    "num_workers": 12,
}

# Unet-3D 模型参数
model_params = {
    "n_channels": 1,
    "n_depth": 10,
    "base_channels": 128,
    "learning_rate": 1e-3
}

rf_trainer = BaseTrainer(
    area=area,
    model_class=UNet3D,
    dataset_class=Argo3DTemperatureDataset,
    use_checkpoint=True,
    dataset_params=dataset_params,
    trainer_params=trainer_params,
    model_params=model_params,
    use_wandb=False
)

# %%
# model = rf_trainer.train()
# model = None

# %%
# %% 使用封装的分析函数 - 分析训练好的模型
from src.analysis.model_analysis import analyze_unet3d_model, load_model_safely
from src.models.Profile.UNet3D import UNet3D
import os

print("=" * 100)
print("🔍 选择要分析的模型")
print("=" * 100)

checkpoint_path = '/home/morisi/Workspace/3D-Ocean/out/checkpoints/2025-12-06-18-27/UNet3D.ckpt.ckpt'

print(f"\n✅ 找到checkpoint: {checkpoint_path}")

# 使用安全加载函数
trained_model = load_model_safely(checkpoint_path, model_class=UNet3D)

# 加载真实数据
print("\n📦 加载真实的SST数据...")
from src.dataset.Argo import Argo3DTemperatureDataset
dataset = Argo3DTemperatureDataset(
    lon=[-180, 180],
    lat=[-80, 80],
    depth=[0, 10],
    resolution=2,
    offset=100
)
sample_sst, _ = dataset[0]

print("\n🚀 开始分析训练好的模型...")
print("-" * 100)

# 执行完整分析
results = analyze_unet3d_model(
    model=trained_model,
    sample_data=sample_sst,
    output_dir='out/models/trained_analysis',
    verbose=True
)

print("\n" + "=" * 100)
print("✅ 训练模型分析完成！")
print(f"📁 结果保存在: out/models/trained_analysis/")
print("=" * 100)
# Out:
# ====================================================================================================
# 🔍 选择要分析的模型
# ====================================================================================================
#
# ✅ 找到checkpoint: /home/morisi/Workspace/3D-Ocean/out/checkpoints/2025-12-06-18-27/UNet3D.ckpt.ckpt
# 📦 从Lightning checkpoint加载: /home/morisi/Workspace/3D-Ocean/out/checkpoints/2025-12-06-18-27/UNet3D.ckpt.ckpt
#    checkpoint中无超参数，从state_dict推断...
#    推断得到: base_channels=128
#    手动创建模型: {'base_channels': 128}
#    ✅ 权重加载完成
# ✅ 模型加载成功！
#
# 📦 加载真实的SST数据...
#
# 🚀 开始分析训练好的模型...
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# 🔬 开始 UNet3D 模型完整分析
# ====================================================================================================
#
# 📊 步骤 1/6: 分析模型参数量...
#
# ====================================================================================================
# 📊 UNet3D 模型参数量详细统计
# ====================================================================================================
#
# 🔹 编码器参数统计:
# ----------------------------------------------------------------------------------------------------
#   inc (初始卷积)                    :         149,120 (  0.15M)
#   down1 (第1次下采样)                :         885,760 (  0.89M)
#   down2 (第2次下采样)                :       3,540,992 (  3.54M)
#   down3 (第3次下采样)                :      14,159,872 ( 14.16M)
#   down4 (瓶颈层)                   :      56,631,296 ( 56.63M)
#
# 🔹 解码器参数统计:
# ----------------------------------------------------------------------------------------------------
#   up1 (第1次上采样)                  :      36,705,280 ( 36.71M)
#   up2 (第2次上采样)                  :       9,177,600 (  9.18M)
#   up3 (第3次上采样)                  :       2,295,040 (  2.30M)
#   up4 (第4次上采样)                  :         574,080 (  0.57M)
#   outc (输出层)                    :           1,290 (  0.00M)
#
# ====================================================================================================
# 📈 总参数量: 124,120,330 (124.12M)
#    • 编码器参数: 75,367,040 (75.37M) - 60.7%
#    • 解码器参数: 48,753,290 (48.75M) - 39.3%
# ====================================================================================================
#
# 👁️  步骤 2/6: 计算感受野...
#
# ====================================================================================================
# 👁️  UNet3D 感受野 (Receptive Field) 分析
# ====================================================================================================
#
# 感受野大小详情:
# ----------------------------------------------------------------------------------------------------
# 层名称                            感受野大小 (像素)           累积步长            类型
# ----------------------------------------------------------------------------------------------------
#   inc (初始卷积)                   5                    1               编码器
#   down1 (下采样1)                 15                   2               编码器
#   down2 (下采样2)                 35                   4               编码器
#   down3 (下采样3)                 75                   8               编码器
# ⭐ down4 (瓶颈层)                  155                  16              瓶颈
#   up1 (上采样1)                   187                  8               解码器
#   up2 (上采样2)                   203                  4               解码器
#   up3 (上采样3)                   211                  2               解码器
#   up4 (上采样4)                   215                  1               解码器
# ----------------------------------------------------------------------------------------------------
#
# 🌍 物理意义:
#   • 最终感受野: 215 像素
#   • 在 2° 分辨率下: 约覆盖 430° 的地理范围
#   • 在 1° 分辨率下: 约覆盖 215° 的地理范围
#
#   这意味着模型在重建某一点的温度剖面时，会考虑周围 215 个网格点的信息，
#   能够捕捉中尺度海洋现象（涡旋、锋面、上升流等）对温度剖面的影响。
# ====================================================================================================
#
# 🎨 步骤 3/6: 可视化特征图...
#
# 输入数据形状: torch.Size([1, 1, 80, 180])
# 输出数据形状: torch.Size([1, 10, 80, 180])
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 36755 (\N{CJK UNIFIED IDEOGRAPH-8F93}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 20837 (\N{CJK UNIFIED IDEOGRAPH-5165}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 36755 (\N{CJK UNIFIED IDEOGRAPH-8F93}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 28145 (\N{CJK UNIFIED IDEOGRAPH-6DF1}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23618 (\N{CJK UNIFIED IDEOGRAPH-5C42}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 26174 (\N{CJK UNIFIED IDEOGRAPH-663E}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 31034 (\N{CJK UNIFIED IDEOGRAPH-793A}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 31532 (\N{CJK UNIFIED IDEOGRAPH-7B2C}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 32534 (\N{CJK UNIFIED IDEOGRAPH-7F16}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 30721 (\N{CJK UNIFIED IDEOGRAPH-7801}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 35299 (\N{CJK UNIFIED IDEOGRAPH-89E3}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 36807 (\N{CJK UNIFIED IDEOGRAPH-8FC7}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 21487 (\N{CJK UNIFIED IDEOGRAPH-53EF}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 35270 (\N{CJK UNIFIED IDEOGRAPH-89C6}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:349: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 36755 (\N{CJK UNIFIED IDEOGRAPH-8F93}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 20837 (\N{CJK UNIFIED IDEOGRAPH-5165}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 36755 (\N{CJK UNIFIED IDEOGRAPH-8F93}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph
) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23618 (\N{CJK UNIFIED IDEOGRAPH-5C42}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 26174 (\N{CJK UNIFIED IDEOGRAPH-663E}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 31034 (\N{CJK UNIFIED IDEOGRAPH-793A}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 31532 (\N{CJK UNIFIED IDEOGRAPH-7B2C}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 36755 (\N{CJK UNIFIED IDEOGRAPH-8F93}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 28145 (\N{CJK UNIFIED IDEOGRAPH-6DF1}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 23618 (\N{CJK UNIFIED IDEOGRAPH-5C42}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 29366 (\N{CJK UNIFIED IDEOGRAPH-72B6}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 26174 (\N{CJK UNIFIED IDEOGRAPH-663E}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 31034 (\N{CJK UNIFIED IDEOGRAPH-793A}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 31532 (\N{CJK UNIFIED IDEOGRAPH-7B2C}) missing from font(s) DejaVu Sans.
# ...
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 8419 (\N{COMBINING ENCLOSING KEYCAP}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 21407 (\N{CJK UNIFIED IDEOGRAPH-539F}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 22987 (\N{CJK UNIFIED IDEOGRAPH-59CB}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 36755 (\N{CJK UNIFIED IDEOGRAPH-8F93}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20837 (\N{CJK UNIFIED IDEOGRAPH-5165}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 38470 (\N{CJK UNIFIED IDEOGRAPH-9646}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 22320 (\N{CJK UNIFIED IDEOGRAPH-5730}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20026 (\N{CJK UNIFIED IDEOGRAPH-4E3A}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 25513 (\N{CJK UNIFIED IDEOGRAPH-63A9}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 30721 (\N{CJK UNIFIED IDEOGRAPH-7801}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 32418 (\N{CJK UNIFIED IDEOGRAPH-7EA2}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 33394 (\N{CJK UNIFIED IDEOGRAPH-8272}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 32511 (\N{CJK UNIFIED IDEOGRAPH-7EFF}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 28023 (\N{CJK UNIFIED IDEOGRAPH-6D77}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 27915 (\N{CJK UNIFIED IDEOGRAPH-6D0B}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 26367 (\N{CJK UNIFIED IDEOGRAPH-66FF}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 25442 (\N{CJK UNIFIED IDEOGRAPH-6362}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20110 (\N{CJK UNIFIED IDEOGRAPH-4E8E}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 21521 (\N{CJK UNIFIED IDEOGRAPH-5411}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20256 (\N{CJK UNIFIED IDEOGRAPH-4F20}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 25773 (\N{CJK UNIFIED IDEOGRAPH-64AD}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 27169 (\N{CJK UNIFIED IDEOGRAPH-6A21}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 22411 (\N{CJK UNIFIED IDEOGRAPH-578B}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 26368 (\N{CJK UNIFIED IDEOGRAPH-6700}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 32456 (\N{CJK UNIFIED IDEOGRAPH-7EC8}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 24674 (\N{CJK UNIFIED IDEOGRAPH-6062}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 22797 (\N{CJK UNIFIED IDEOGRAPH-590D}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 27973 (\N{CJK UNIFIED IDEOGRAPH-6D45}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20013 (\N{CJK UNIFIED IDEOGRAPH-4E2D}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# ✅ NaN处理机制图已保存至: out/models/trained_analysis/nan_handling_mechanism.png
#
# ====================================================================================================
# 💡 NaN处理机制的优点:
#   1. ✅ 避免NaN导致的梯度消失和计算错误
#   2. ✅ 前向传播时用0填充，不影响海洋区域的特征提取
#   3. ✅ 损失函数只计算海洋区域，陆地不参与训练
#   4. ✅ 预测输出恢复陆地NaN，保持物理意义
#   5. ✅ 可视化时陆地显示为灰色，清晰区分海陆
# ====================================================================================================
#
# 🎯 步骤 6/6: 生成完整流程图...
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:691: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 34920 (\N{CJK UNIFIED IDEOGRAPH-8868}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 28201 (\N{CJK UNIFIED IDEOGRAPH-6E29}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 29942 (\N{CJK UNIFIED IDEOGRAPH-74F6}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 39048 (\N{CJK UNIFIED IDEOGRAPH-9888}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 23618 (\N{CJK UNIFIED IDEOGRAPH-5C42}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 26368 (\N{CJK UNIFIED IDEOGRAPH-6700}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 28145 (\N{CJK UNIFIED IDEOGRAPH-6DF1}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 21078 (\N{CJK UNIFIED IDEOGRAPH-5256}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 38754 (\N{CJK UNIFIED IDEOGRAPH-9762}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 23436 (\N{CJK UNIFIED IDEOGRAPH-5B8C}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 25972 (\N{CJK UNIFIED IDEOGRAPH-6574}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 27969 (\N{CJK UNIFIED IDEOGRAPH-6D41}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 32452 (\N{CJK UNIFIED IDEOGRAPH-7EC4}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/src/analysis/model_analysis.py:693: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 34920 (\N{CJK UNIFIED IDEOGRAPH-8868}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 28201 (\N{CJK UNIFIED IDEOGRAPH-6E29}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 21078 (\N{CJK UNIFIED IDEOGRAPH-5256}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 38754 (\N{CJK UNIFIED IDEOGRAPH-9762}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# ✅ 完整流程图已保存至: out/models/trained_analysis/unet3d_complete_pipeline.png
#
# ====================================================================================================
# 🌟 模型设计的关键创新点:
# ====================================================================================================
#
# 1️⃣  **U型对称架构**: 平衡编码器的特征提取和解码器的重建能力
# 2️⃣  **跳跃连接机制**: 编码器特征直接传递到解码器对应层
# 3️⃣  **多尺度特征融合**: 从局部梯度到全球模式的层次化理解
# 4️⃣  **NaN容错处理**: 正确处理海陆边界，确保模型稳健
# 5️⃣  **端到端学习**: 自动学习表层-深层温度的复杂非线性关系
# 6️⃣  **深度维度生成**: 统一框架下重建整个3D温度场
# 7️⃣  **参数高效**: 可在单GPU上训练，支持全球尺度预测
#
# ====================================================================================================
#
# ====================================================================================================
# ✅ 分析完成！所有结果已保存至: out/models/trained_analysis
# ====================================================================================================
#
# ====================================================================================================
# ✅ 训练模型分析完成！
# 📁 结果保存在: out/models/trained_analysis/
# ====================================================================================================
