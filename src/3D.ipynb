# %%
# %reload_ext autoreload
# %autoreload 2
import sys
import arrow

sys.path.append('/home/morisi/Workspace/3D-Ocean')

from src.config.area import Area
from src.trainer.base import BaseTrainer, BasePrediction
from src.dataset.Argo import Argo3DTemperatureDataset, ArgoDepthMap
from src.models.Profile.UNet3D import UNet3D
# Out:
# /home/morisi/Workspace/3D-Ocean/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
area = Area("global_rf_model", [-180, 180], [-80, 80], "global")

depth = [0, 10]

dataset_params = {
    "depth": depth,
    "resolution": 2
}

# 训练器参数
trainer_params = {
    "epochs": 500,
    "batch_size": 32,
    "num_workers": 12,
}

# Unet-3D 模型参数
model_params = {
    "n_channels": 1,
    "n_depth": 10,
    "base_channels": 128,
    "learning_rate": 1e-3
}

rf_trainer = BaseTrainer(
    area=area,
    model_class=UNet3D,
    dataset_class=Argo3DTemperatureDataset,
    use_checkpoint=True,
    dataset_params=dataset_params,
    trainer_params=trainer_params,
    model_params=model_params,
    use_wandb=False
)

# %%
# model = rf_trainer.train()
# model = None

# %%
# %% Nature级别分析 - 生成学术论文图片
from src.analysis.profile import analyze_unet3d_nature, load_model_safely
from src.models.Profile.UNet3D import UNet3D
from src.dataset.Argo import Argo3DTemperatureDataset
import os

train_id = '2025-12-07-16-23'
checkpoint_path = f'/home/morisi/Workspace/3D-Ocean/out/checkpoints/{train_id}/UNet3D.ckpt'

if os.path.exists(checkpoint_path):
    print("=" * 100)
    print("🎓 Nature-Quality Analysis")
    print("=" * 100)
    
    # 加载训练好的模型
    print(f"\n✅ Loading checkpoint: {checkpoint_path}")
    model = load_model_safely(checkpoint_path, model_class=UNet3D)
    
    # 加载真实SST数据
    print("\n📦 Loading real SST data...")
    dataset = Argo3DTemperatureDataset(
        lon=[-180, 180],
        lat=[-80, 80],
        depth=[0, 10],
        resolution=2,
        offset=200
    )
    sample_sst, _ = dataset[0]
    
    # 生成所有Nature级别的图片
    print("\n🚀 Generating Nature-quality figures...")
    print("-" * 100)
    
    results = analyze_unet3d_nature(
        model=model,
        sample_data=sample_sst,
        output_dir='out/models/nature',
        groups=['fig1_architecture', 'fig2_feature_maps', 
                'fig3_skip_connections', 'fig4_nan_handling',
                'fig5_vertical_reconstruction', 'fig6_temperature_profiles'],
        verbose=True
    )
    
    print("\n" + "=" * 100)
    print("✅ All Nature-quality figures generated!")
    print(f"📁 Saved to: out/models/nature/")
    print("\n📊 Static Figures (PNG, 600 DPI):")
    print("  • Figure1_Architecture.png          - Model structure and parameters")
    print("  • Figure2_FeatureMaps.png          - Feature extraction process")
    print("  • Figure3_SkipConnections.png      - Skip connection impact")
    print("  • Figure4_NaNHandling.png          - Land-ocean separation")
    print("  • Figure5_VerticalReconstruction.png - 3D vertical reconstruction")
    print("\n🌐 Interactive Visualization (HTML):")
    print("  • Figure5_Interactive3D.html       - Interactive 3D temperature field")
    print("    (Open in browser for interactive exploration)")
    print("\n📄 Figure Legends:")
    print("  • Figure_Legends.md                - Detailed academic figure captions")
    print("=" * 100)
else:
    print(f"⚠️  Checkpoint not found: {checkpoint_path}")
    print("Please train the model first or check the checkpoint path.")
# Out:
# ...
# 🎓 Nature-Quality Analysis
# ...
#
# ✅ Loading checkpoint: /home/morisi/Workspace/3D-Ocean/out/checkpoints/2025-12-07-16-23/UNet3D.ckpt
# 📦 Loading from Lightning checkpoint: /home/morisi/Workspace/3D-Ocean/out/checkpoints/2025-12-07-16-23/UNet3D.ckpt
#    Inferring parameters from state_dict...
#    Inferred: base_channels=128
#    Creating model manually: {'base_channels': 128}
#    ✅ Weights loaded
# ✅ Model loaded successfully!
#
# 📦 Loading real SST data...
#
# 🚀 Generating Nature-quality figures...
# ----------------------------------------------------------------------------------------------------
# ...
# 🔬 UNet3D Model Analysis - Nature Quality Figures
# ...
#
# 📊 Figure 1: Model Architecture and Parameters...
# /home/morisi/Workspace/3D-Ocean/src/analysis/profile.py:260: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ✅ Figure 1 saved: out/models/nature/Figure1_Architecture.png
#
# ...
