# %%
# %reload_ext autoreload
# %autoreload 2
import sys
sys.path.append('/home/morisi/Workspace/3D-Ocean')

# %%
# %% 三维温度场反演 - 三模型对比训练
from src.trainer.profile import ProfileTrainer

# 初始化训练器
trainer = ProfileTrainer(
    lon_range=[-180, 180],
    lat_range=[-60, 60],
    depth_range=[0, 30],  # 0-380m（30个深度层）
    resolution=2
)

# 训练 Thermocline 和 Random Forest
trainer.train_thermocline()
trainer.train_random_forest()

# 训练 UNet3D（30层深度，与其他模型一致）
trainer.train_unet3d(
    n_depth=30,           # 30层深度（0-380m）
    epochs=200,
    batch_size=8,
    learning_rate=1e-3,
    base_channels=160,
    force_retrain=True    # 强制重新训练
)
# Out:
# ...
# 📦 加载 Argo 数据集
# ...
#    经度范围: [-180, 180]
#    纬度范围: [-60, 60]
#    深度范围: 0m - 380m
#    空间分辨率: 2°
#
#    总样本数: 242 个月
#    训练样本: 193 个月
#    测试样本: 49 个月
# ...
# 加载测试数据: 100%|██████████| 49/49 [00:01<00:00, 46.70it/s]
#    训练 SST 形状: (193, 60, 180)
#    训练剖面形状: (193, 60, 180, 30)
#
# ...
# 🌡️ 训练 Thermocline 模型
# ...
# Thermocline 预测: 100%|██████████| 49/49 [00:00<00:00, 268.62it/s]
#    ✅ Thermocline 总体 RMSE: 2.391°C
#
# ...
# 🌲 训练 Random Forest 模型
# ...
#    有效训练样本: 1396548
#    训练中 (n_estimators=400, max_depth=20)...
#    ✅ Random Forest 总体 RMSE: 2.274°C
#
# ...
# 🧠 训练/加载 UNet3D 模型
# ...
#    输出深度层数: 30
#    使用设备: cuda
#    开始训练 UNet3D...
#    参数: epochs=200, batch_size=8, lr=0.001
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ...

# %%
# %% 打印结果摘要
trainer.print_summary()
# Out:
# ...
# 📊 三模型 RMSE 对比
# ...
#
# 深度(m)     THERMOCLINE    UNET3D         RF
# -------------------------------------------------------
# 0         0.000          0.255          0.004
# 5         0.270          0.339          0.271
# 10        0.292          0.345          0.292
# 20        0.550          0.463          0.551
# 30        1.041          0.649          1.045
# 40        1.559          0.775          1.565
# 50        2.007          0.853          2.015
# 60        2.360          0.904          2.368
# 70        2.624          0.929          2.631
# 80        2.818          0.939          2.822
# 90        2.957          0.942          2.955
# 100       3.054          0.942          3.041
# 110       3.117          0.937          3.093
# 120       3.158          0.931          3.116
# 130       3.178          0.918          3.117
# 140       3.179          0.901          3.097
# 150       3.166          0.888          3.063
# 160       3.143          0.867          3.018
# ...

# %%
# %% 绘制三模型 RMSE 对比图
trainer.plot_comparison()
# Out:
# ✅ 保存: /home/morisi/Workspace/3D-Ocean/out/models/three_models_rmse_comparison.png
